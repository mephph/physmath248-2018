# %% [markdown]
# # Review of basic features of the ipython notebook

# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = linspace(1,7,10)

# %%
close(1),figure(1)
plot(x,sin(x),'r--', label='sin')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot(x,cos(x),label='cos')

# %%
legend(loc=0)
xlabel('x'); ylabel("sin, cos")

# %%
x = linspace(1,5,50)
